# %%
# !pip install pydicom
# !pip install matplotlib

# %%
#pip list -v pydicom 2.3.0
print(ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.23488913642874260913373207617986166508
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002, 0013) Implementation Version Name         SH: '0.5'
# (0002, 0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '19770727'
# (0008, 0013) Instance Creation Time              TM: '081000'
# ...

# %%
from pydicom import dcmread
from pydicom.data import get_testdata_file
import matplotlib.pyplot as plt
from IPython.display import clear_output

for i in range(1,292):
    if i<10: ds = dcmread(f"/Users/eileenwang/Downloads/dataset1_Thorax_Abdomen/IM-0001-000{i}.dcm")
    elif i<100: ds = dcmread(f"/Users/eileenwang/Downloads/dataset1_Thorax_Abdomen/IM-0001-00{i}.dcm")
    else: ds = dcmread(f"/Users/eileenwang/Downloads/dataset1_Thorax_Abdomen/IM-0001-0{i}.dcm")
    fig = plt.figure()
    fig.suptitle(f'This is the only set {i}th image', fontsize=16)
    plt.imshow(ds.pixel_array)
    plt.show()
    clear_output(wait  = True)

# %%
# image shape
print((ds.pixel_array).shape)
# Out:
# (512, 512)

# %%
# dcm info output
# import json
# file = ds.to_json_dict()

# jsonString = json.dumps(file)
# jsonFile = open("data.json", "w")
# jsonFile.write(jsonString)
# jsonFile.close()

# %%
import os

list = os.listdir("/Users/eileenwang/Desktop/lung/manifest-1656927542033/APOLLO-5-LUAD/AP-78LL/07-27-1977-NA-CT CHEST WO CON-49429/5.000000-THIN LUNG WINDOW-34614") # dir is your directory path
number_files = len(list)
print (number_files)
# Out:
# 281

# %%
# What I found from cancer imaging archive (open source)
# https://www.cancerimagingarchive.net/collections/

import os
from pydicom import dcmread
import matplotlib.pyplot as plt
from IPython.display import clear_output

# "2.000000-CT CHEST-28012",
folder = ["3.000000-.625 CT CHEST-31776","4.000000-THINS CHEST STD-03776","5.000000-THIN LUNG WINDOW-34614"]
for j in range(3):
    list = os.listdir(f"/Users/eileenwang/Desktop/lung/manifest-1656927542033/APOLLO-5-LUAD/AP-78LL/07-27-1977-NA-CT CHEST WO CON-49429/{folder[j]}") # dir is your directory path

    for i in range(len(list)):
        if i<9: ds = dcmread(f'/Users/eileenwang/Desktop/lung/manifest-1656927542033/APOLLO-5-LUAD/AP-78LL/07-27-1977-NA-CT CHEST WO CON-49429/{folder[j]}/1-00{i+1}.dcm')
        elif i <99: ds = dcmread(f'/Users/eileenwang/Desktop/lung/manifest-1656927542033/APOLLO-5-LUAD/AP-78LL/07-27-1977-NA-CT CHEST WO CON-49429/{folder[j]}/1-0{i+1}.dcm')
        else: ds = dcmread(f'/Users/eileenwang/Desktop/lung/manifest-1656927542033/APOLLO-5-LUAD/AP-78LL/07-27-1977-NA-CT CHEST WO CON-49429/{folder[j]}/1-{i+1}.dcm')
        fig = plt.figure()
        fig.suptitle(f'This is the {j+1}th set {i}th image', fontsize=16)
        plt.imshow(ds.pixel_array)
        plt.show()
        clear_output(wait  = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/k0/zssy_hqd6_j9tvhzj0y_ltfh0000gn/T/ipykernel_1217/1039977415.py in <module>
#      19         fig.suptitle(f'This is the {j+1}th set {i}th image', fontsize=16)
#      20         plt.imshow(ds.pixel_array)
# ---> 21         plt.show()
#      22         clear_output(wait  = True)
#
# ~/opt/anaconda3/envs/objectDetection/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     387     """
#     388     _warn_if_gui_out_of_main_thread()
# --> 389     return _get_backend_mod().show(*args, **kwargs)
#     390
#     391
#
# ~/opt/anaconda3/envs/objectDetection/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ...

# %%
# image shape
print((ds.pixel_array).shape)
# Out:
# (512, 512)
